# %% [markdown]
# # download dati da exchange
#
# per poter efettuare il backtest sono necessari i dati dello storico dell'andamento del prezzo.
#
# i dati una volta scaricati vengono salvati in file nella cartella `data/`.
# le successice esecuzioni della funzione `DataFetcher.download_data()` andranno a recuperare solo i dati mancanti.

# %%
from datafetcher import DataFetcher
from strategies import *
import logging
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO, datefmt='%d/%m/%Y %H:%M:%S')

# %%
dfetch = DataFetcher()

# %%
dfetch.download_data(exchange='bitmex', symbol='XBTUSD', bin_size='1d')
# Out:
#                              close  foreignNotional  ...      volume       vwap
# timestamp                                            ...
# 2015-09-26 00:00:00+00:00   235.20     1.057927e+05  ...      190090   235.9100
# 2015-09-27 00:00:00+00:00   234.51     1.415267e+05  ...      258488   233.9900
# 2015-09-28 00:00:00+00:00   233.29     8.782600e+04  ...      161013   233.5500
# 2015-09-29 00:00:00+00:00   240.07     1.807558e+05  ...      319143   237.9810
# 2015-09-30 00:00:00+00:00   237.00     2.093607e+05  ...      368771   238.2660
# ...                            ...              ...  ...         ...        ...
# 2020-05-13 00:00:00+00:00  8822.50     2.175541e+09  ...  2175540768  8781.1732
# 2020-05-14 00:00:00+00:00  9314.50     2.308094e+09  ...  2308094044  9088.4304
# 2020-05-15 00:00:00+00:00  9801.50     3.582078e+09  ...  3582078491  9646.9226
# 2020-05-16 00:00:00+00:00  9315.50     3.557587e+09  ...  3557587206  9477.7746
# ...

# %%
dfetch.download_data(exchange='bitmex', symbol='XBTUSD', bin_size='1h')
# Out:
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
#                              close  foreignNotional  ...     volume       vwap
# timestamp                                            ...
# 2015-09-25 13:00:00+00:00   237.45     6.482807e+03  ...      11501   237.4180
# 2015-09-25 14:00:00+00:00   236.08     1.262713e+04  ...      22625   236.2420
# 2015-09-25 15:00:00+00:00   236.34     9.731871e+03  ...      17434   236.2650
# 2015-09-25 16:00:00+00:00   235.71     1.494821e+04  ...      26900   235.7320
# 2015-09-25 17:00:00+00:00   235.75     1.623474e+04  ...      29200   235.7930
# ...                            ...              ...  ...        ...        ...
# 2020-05-17 10:00:00+00:00  9490.00     3.919210e+07  ...   39192102  9488.5663
# 2020-05-17 11:00:00+00:00  9537.50     3.850514e+07  ...   38505141  9523.8095
# 2020-05-17 12:00:00+00:00  9528.50     3.340219e+07  ...   33402189  9518.3705
# 2020-05-17 13:00:00+00:00  9785.00     3.956478e+08  ...  395647776  9704.9689
# ...
